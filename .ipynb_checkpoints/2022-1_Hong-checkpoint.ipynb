# %% [markdown]
# ## Plot XRF data

# %%
sys.path.append('/home/beams/USERBNP/scripts/graceluo/bnp/APS2021c2/')
import h5py, os, collections, sys
from load_h5_bnp import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def loadscan():
    pv_angle = b'9idbTAU:SM:ST:ActPos'
    primary_dir = '/mnt/micdata1/bnp/2022-1/Hong/'
    fdir = os.path.join(primary_dir,'img.dat')
    # # output_dir = os.path.join(primary_dir, 'output')
    img_tags = ['MAPS']
    #img_tags = ['MAPS', 'exchange_1', 'exchange_2', 'exchange_3', 'exchange_4']
    elms = [['Si', 'S', 'Ca', 'Zn', 'K', 'P', 'Fe', 'Cu', 'Cl', ]]
    smp_name = 'Ecoli'
    # img_def = ['XRF_roi', 'XRF_roi_plus', 'XRF_fits', 'XRF_fits/ds_ic']
    bnp_loadh5 = {}
    bnp_data = {}

    for img_tag, tag_elm in zip(img_tags, elms):
         # Create a load_h5_bnp class object
        bnp_d = load_h5_bnp(smp_name, fdir, img_tag, pv_angle, tag_elm)
         # Perform load action
        bnp_d.load_h5(padding=True, printch=False)
        bnp_data[img_tag] = bnp_d.data_pd
    return bnp_data

# %%
bnp_data = loadscan()
bnp_dataf = bnp_data['MAPS']
scan_num = bnp_dataf['scan_num']
for s in scan_num:
    sel = bnp_dataf[bnp_dataf['scan_num'] == s]
    elms = ['P', 'S', 'Cl', 'K', 'Ca', 'Fe', 'Cu', 'Zn']
    fig, ax = plt.subplots(2, 4, figsize = (10,5))
    for e, ax_ in zip(elms, ax.ravel()):
        d = sel[e].values[0]
        ax_.imshow(d, cmap = 'inferno', vmax = np.mean(d) + 5 * np.std(d))
        ax_.set_title(e)
        ax_.set_xticks([])
        ax_.set_yticks([])
        xrange = abs(sel['xval'].values[0][0] - sel['xval'].values[0][-1])
        yrange = abs(sel['yval'].values[0][0] - sel['yval'].values[0][-1])
        sstep = abs(np.mean(np.diff(sel['xval'].values[0])))
    print('step size: %.2f, area: %d x %d (um2)'%(sstep, xrange, yrange ))
    plt.tight_layout()
#     plt.savefig('/mnt/micdata1/bnp/2022-1/Hong/XRFplots/%s_ss%.2f_area_%dx%d.png'%(s, sstep, xrange, yrange))
# Out:
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0001.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0002.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0003.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0004.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0005.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0006.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0007.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0008.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0009.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0010.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0011.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0012.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0013.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0014.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0015.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0016.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0017.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0018.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0019.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0020.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0021.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0022.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_fly0023.mda.h5
# before tag condition, the current tag is:MAPS
# Loading /mnt/micdata1/bnp/2022-1/Hong/img.dat/bnp_step0001.mda.h5
# step size: 1.00, area: 40 x 39 (um2)
# step size: 1.00, area: 32 x 2 (um2)
# step size: 2.00, area: 60 x 59 (um2)
# step size: 0.20, area: 32 x 45 (um2)
# step size: 1.00, area: 50 x 59 (um2)
# step size: 2.00, area: 80 x 79 (um2)
# step size: 1.00, area: 10 x 2 (um2)
# step size: 1.00, area: 10 x 2 (um2)
# step size: 1.00, area: 10 x 1 (um2)
# step size: 1.00, area: 10 x 2 (um2)
# step size: 1.00, area: 10 x 2 (um2)
# step size: 1.00, area: 10 x 1 (um2)
# step size: 1.00, area: 10 x 2 (um2)
# step size: 1.00, area: 10 x 0 (um2)
# step size: 1.00, area: 10 x 1 (um2)
# step size: 1.00, area: 10 x 9 (um2)
# step size: 2.00, area: 79 x 80 (um2)
# step size: 2.00, area: 80 x 79 (um2)
# step size: 2.00, area: 79 x 80 (um2)
# step size: 1.00, area: 10 x 9 (um2)
# /APSshare/anaconda3/x86_64/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys
# step size: 1.00, area: 10 x 10 (um2)
# step size: 2.00, area: 80 x 320 (um2)
# step size: 2.00, area: 80 x 320 (um2)
# step size: 1.00, area: 10 x 3 (um2)

# %%
abs(np.mean(np.diff(sel['xval'].values[0])))
# Out:
# 0.08

# %%
abs(sel['xval'].values[0][0] - sel['xval'].values[0][-1])
# Out:
# 4.0
